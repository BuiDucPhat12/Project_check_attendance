# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# !gdown 1I3GGJLbpSlY1dNbIDIPKfiuZUdiSa2hq
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1I3GGJLbpSlY1dNbIDIPKfiuZUdiSa2hq
# To: /content/IMDB-Movie-Data.csv
# 100% 310k/310k [00:00<00:00, 105MB/s]

# %%
data = pd.read_csv('/content/IMDB-Movie-Data.csv', index_col = 'Title')

# %%
data.head(5)
# Out:
#                          Rank                     Genre  \
# Title
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Prometheus                  2  Adventure,Mystery,Sci-Fi
# Split                       3           Horror,Thriller
# Sing                        4   Animation,Comedy,Family
# Suicide Squad               5  Action,Adventure,Fantasy
#
#                                                                Description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# Split                    Three girls are kidnapped by a man with a diag...
# Sing                     In a city of humanoid animals, a hustling thea...
# Suicide Squad            A secret government agency recruits some of th...
#
#                                      Director  \
# Title
# Guardians of the Galaxy            James Gunn
# Prometheus                       Ridley Scott
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, Guardians of the Galaxy to Nine Lives
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                1000 non-null   int64
#  1   Genre               1000 non-null   object
#  2   Description         1000 non-null   object
#  3   Director            1000 non-null   object
#  4   Actors              1000 non-null   object
#  5   Year                1000 non-null   int64
#  6   Runtime (Minutes)   1000 non-null   int64
#  7   Rating              1000 non-null   float64
#  8   Votes               1000 non-null   int64
#  9   Revenue (Millions)  872 non-null    float64
#  10  Metascore           936 non-null    float64
# dtypes: float64(3), int64(4), object(4)
# memory usage: 93.8+ KB

# %%
data.describe()
# Out:
#               Rank         Year  Runtime (Minutes)       Rating         Votes  \
# count  1000.000000  1000.000000        1000.000000  1000.000000  1.000000e+03
# mean    500.500000  2012.783000         113.172000     6.723200  1.698083e+05
# std     288.819436     3.205962          18.810908     0.945429  1.887626e+05
# min       1.000000  2006.000000          66.000000     1.900000  6.100000e+01
# 25%     250.750000  2010.000000         100.000000     6.200000  3.630900e+04
# 50%     500.500000  2014.000000         111.000000     6.800000  1.107990e+05
# 75%     750.250000  2016.000000         123.000000     7.400000  2.399098e+05
# max    1000.000000  2016.000000         191.000000     9.000000  1.791916e+06
#
#        Revenue (Millions)   Metascore
# count          872.000000  936.000000
# mean            82.956376   58.985043
# std            103.253540   17.194757
# min              0.000000   11.000000
# 25%             13.270000   47.000000
# ...

# %% [markdown]
# - min max Year range from 2006 - 2016
# - Rating average is 6.723200, min is 1.900000, max is 9.000000
# - Max revenue is 936.630000

# %% [markdown]
# # Data Selection - Indexing and Slicing data

# %%
#Extract Genre as a Series
Genre = data['Genre']
Genre
# Out:
# Title
# Guardians of the Galaxy     Action,Adventure,Sci-Fi
# Prometheus                 Adventure,Mystery,Sci-Fi
# Split                               Horror,Thriller
# Sing                        Animation,Comedy,Family
# Suicide Squad              Action,Adventure,Fantasy
#                                      ...
# Secret in Their Eyes            Crime,Drama,Mystery
# Hostel: Part II                              Horror
# Step Up 2: The Streets          Drama,Music,Romance
# Search Party                       Adventure,Comedy
# Nine Lives                    Comedy,Family,Fantasy
# Name: Genre, Length: 1000, dtype: object

# %%
#Extract Genre as a DataFrames
Genre_Description = data[['Genre','Description']]
Genre_Description
# Out:
#                                             Genre  \
# Title
# Guardians of the Galaxy   Action,Adventure,Sci-Fi
# Prometheus               Adventure,Mystery,Sci-Fi
# Split                             Horror,Thriller
# Sing                      Animation,Comedy,Family
# Suicide Squad            Action,Adventure,Fantasy
# ...                                           ...
# Secret in Their Eyes          Crime,Drama,Mystery
# Hostel: Part II                            Horror
# Step Up 2: The Streets        Drama,Music,Romance
# Search Party                     Adventure,Comedy
# Nine Lives                  Comedy,Family,Fantasy
#
#                                                                Description
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# Split                    Three girls are kidnapped by a man with a diag...
# ...

# %%
data.reset_index(inplace = True)

# %% [markdown]
# tách các hàng thứ 10 đến thứ 15 và dựa vào hình kết quả dưới để hoàn thiện đoạn code sau:

# %%
get_column = data.loc[10:15, 'Rating':'Revenue (Millions)']
get_column
# Out:
#     Rating   Votes  Revenue (Millions)
# 10     7.5  232072              234.02
# 11     7.8   93103              169.27
# 12     7.9  323118              532.17
# 13     7.7  118151              248.75
# 14     6.4    8612                2.87
# 15     6.6  120259              368.31

# %%
data.set_index('Title', inplace = True)

# %% [markdown]
# # Data Selection – Based on Conditional filtering

# %% [markdown]
#  Lấy các bộ phim từ 2010 tới 2015, với rating nhỏ hơn 6.0 nhưng lại có doanh thu thuộc top 5% trên toàn bộ dataset.

# %%
revenue_threshold = data['Revenue (Millions)'].quantile(0.95)

get_data = data[(data['Year'] >= 2010) &
              (data['Year'] <= 2015) &
                (data['Rating'] < 6.0) &
                (data['Revenue (Millions)'] >= revenue_threshold)]
get_data
# Out:
#                             Rank                    Genre  \
# Title
# The Twilight Saga: Eclipse   942  Adventure,Drama,Fantasy
#
#                                                                   Description  \
# Title
# The Twilight Saga: Eclipse  As a string of mysterious killings grips Seatt...
#
#                                Director  \
# Title
# The Twilight Saga: Eclipse  David Slade
#
#                                                                        Actors  \
# Title
# The Twilight Saga: Eclipse  Kristen Stewart, Robert Pattinson, Taylor Laut...
#
#                             Year  Runtime (Minutes)  Rating   Votes  \
# Title
# The Twilight Saga: Eclipse  2010                124     4.9  192740
#
#                             Revenue (Millions)  Metascore
# Title
# The Twilight Saga: Eclipse              300.52       58.0

# %% [markdown]
# # Groupby Operations

# %%
Direct_rating = data.groupby("Director")[['Rating']].mean()
Direct_rating
# Out:
#                      Rating
# Director
# Aamir Khan             8.50
# Abdellatif Kechiche    7.80
# Adam Leon              6.50
# Adam McKay             7.00
# Adam Shankman          6.30
# ...                     ...
# Xavier Dolan           7.55
# Yimou Zhang            6.10
# Yorgos Lanthimos       7.20
# Zack Snyder            7.04
# Zackary Adler          5.10
#
# [644 rows x 1 columns]

# %% [markdown]
# # Sorting Operations

# %% [markdown]
# top 5 đạo diễn đạt số rating trung bình cao nhất.

# %%
sorted_values = Direct_rating.sort_values(by = 'Rating', ascending = False)
sorted_values.head(5)
# Out:
#                                   Rating
# Director
# Nitesh Tiwari                       8.80
# Christopher Nolan                   8.68
# Olivier Nakache                     8.60
# Makoto Shinkai                      8.60
# Florian Henckel von Donnersmarck    8.50

# %%
data.isnull().sum()
# Out:
# Rank                    0
# Genre                   0
# Description             0
# Director                0
# Actors                  0
# Year                    0
# Runtime (Minutes)       0
# Rating                  0
# Votes                   0
# Revenue (Millions)    128
# Metascore              64
# dtype: int64

# %%
data.drop('Metascore', axis = 1)
# Out:
#                          Rank                     Genre  \
# Title
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Prometheus                  2  Adventure,Mystery,Sci-Fi
# Split                       3           Horror,Thriller
# Sing                        4   Animation,Comedy,Family
# Suicide Squad               5  Action,Adventure,Fantasy
# ...                       ...                       ...
# Secret in Their Eyes      996       Crime,Drama,Mystery
# Hostel: Part II           997                    Horror
# Step Up 2: The Streets    998       Drama,Music,Romance
# Search Party              999          Adventure,Comedy
# Nine Lives               1000     Comedy,Family,Fantasy
#
#                                                                Description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# ...

# %%
data.dropna().isnull().sum()
# Out:
# Rank                  0
# Genre                 0
# Description           0
# Director              0
# Actors                0
# Year                  0
# Runtime (Minutes)     0
# Rating                0
# Votes                 0
# Revenue (Millions)    0
# Metascore             0
# dtype: int64

# %%
data.isnull().sum()
# Out:
# Rank                    0
# Genre                   0
# Description             0
# Director                0
# Actors                  0
# Year                    0
# Runtime (Minutes)       0
# Rating                  0
# Votes                   0
# Revenue (Millions)    128
# Metascore              64
# dtype: int64

# %% [markdown]
# # Dealing with missing values - Filling

# %%
revenue_mean = data['Revenue (Millions)'].mean()
print("The mean revenue is: ", revenue_mean)
# Out:
# The mean revenue is:  82.95637614678898

# %%
data["Revenue (Millions)"].fillna(revenue_mean, inplace=True)
data.isnull().sum()
# Out:
# /tmp/ipython-input-1024331475.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data["Revenue (Millions)"].fillna(revenue_mean, inplace=True)
# Rank                   0
# Genre                  0
# Description            0
# Director               0
# Actors                 0
# Year                   0
# Runtime (Minutes)      0
# Rating                 0
# Votes                  0
# Revenue (Millions)     0
# Metascore             64
# dtype: int64

# %% [markdown]
# #apply() functions

# %%
def rating_good(rating):
  if rating >= 7.5:
    return 'Good'
  elif rating >= 6.0:
    return 'Average'
  else:
    return 'Bad'


data["Rating_category"] = data['Rating'].apply(rating_good)
data[['Rating',"Rating_category"]].head()
# Out:
#                          Rating Rating_category
# Title
# Guardians of the Galaxy     8.1            Good
# Prometheus                  7.0         Average
# Split                       7.3         Average
# Sing                        7.2         Average
# Suicide Squad               6.2         Average

# %% [markdown]
# # Time Series Dataset

# %%
# !gdown 1qW7tPUw3u3Dn4kuBEoV8XwLYpetBDVjr
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1qW7tPUw3u3Dn4kuBEoV8XwLYpetBDVjr
# To: /content/opsd_germany_daily.csv
# 100% 222k/222k [00:00<00:00, 100MB/s]

# %%
germany_daily = pd.read_csv('/content/opsd_germany_daily.csv')
germany_daily.head()
# Out:
#          Date  Consumption  Wind  Solar  Wind+Solar
# 0  2006-01-01     1069.184   NaN    NaN         NaN
# 1  2006-01-02     1380.521   NaN    NaN         NaN
# 2  2006-01-03     1442.533   NaN    NaN         NaN
# 3  2006-01-04     1457.217   NaN    NaN         NaN
# 4  2006-01-05     1477.131   NaN    NaN         NaN

# %%
print(germany_daily.dtypes)
print(germany_daily.shape)
# Out:
# Date            object
# Consumption    float64
# Wind           float64
# Solar          float64
# Wind+Solar     float64
# dtype: object
# (4383, 5)

# %%
germany_daily.set_index('Date', inplace = True)
germany_daily.head()
# Out:
#             Consumption  Wind  Solar  Wind+Solar
# Date
# 2006-01-01     1069.184   NaN    NaN         NaN
# 2006-01-02     1380.521   NaN    NaN         NaN
# 2006-01-03     1442.533   NaN    NaN         NaN
# 2006-01-04     1457.217   NaN    NaN         NaN
# 2006-01-05     1477.131   NaN    NaN         NaN

# %%
opsd_daily = pd.read_csv('/content/opsd_germany_daily.csv', index_col=0, parse_dates=True)
opsd_daily["Year"] = opsd_daily.index.year
opsd_daily["Month"] = opsd_daily.index.month
opsd_daily["Weekday Name"] = opsd_daily.index.day_name()
opsd_daily.sample(5, random_state=0)
# Out:
#             Consumption    Wind    Solar  Wind+Solar  Year  Month Weekday Name
# Date
# 2008-08-23     1152.011     NaN      NaN         NaN  2008      8     Saturday
# 2013-08-08     1291.984  79.666   93.371     173.037  2013      8     Thursday
# 2009-08-27     1281.057     NaN      NaN         NaN  2009      8     Thursday
# 2015-10-02     1391.050  81.229  160.641     241.870  2015     10       Friday
# 2009-06-02     1201.522     NaN      NaN         NaN  2009      6      Tuesday

# %%
opsd_daily.loc['2014-01-20':'2014-01-22']
# Out:
#             Consumption    Wind   Solar  Wind+Solar  Year  Month Weekday Name
# Date
# 2014-01-20     1590.687  78.647   6.371      85.018  2014      1       Monday
# 2014-01-21     1624.806  15.643   5.835      21.478  2014      1      Tuesday
# 2014-01-22     1625.155  60.259  11.992      72.251  2014      1    Wednesday

# %%
new_opsd_df = opsd_daily.loc["2012-02"]
new_opsd_df.head(5)
# Out:
#             Consumption     Wind   Solar  Wind+Solar  Year  Month Weekday Name
# Date
# 2012-02-01     1511.866  199.607  43.502     243.109  2012      2    Wednesday
# 2012-02-02     1563.407   73.469  44.675     118.144  2012      2     Thursday
# 2012-02-03     1563.631   36.352  46.510      82.862  2012      2       Friday
# 2012-02-04     1372.614   20.551  45.225      65.776  2012      2     Saturday
# 2012-02-05     1279.432   55.522  54.572     110.094  2012      2       Sunday

# %% [markdown]
# # Visualizing time series data:

# %%
import seaborn as sns
import matplotlib as plt

# %%
sns.set(rc = {"figure.figsize":(11, 4)})
opsd_daily['Consumption'].plot(linewidth=0.5)
plt.ylabel('Consumption')
plt.show()

# %%
cols_plot = ["Consumption", "Solar", "Wind"]
axes = opsd_daily[cols_plot].plot(
    subplots=True,
    style='.',
    figsize=(15, 10))
for ax in axes:
  ax.set_ylabel("Daily Totals (GWh)")
plt.show()

# %% [markdown]
# # Seasonality

# %%
fig, axes = plt.subplots (3, 1,figsize = [11,10], sharex = True )
for name, ax in zip(["Consumption", "Solar", "Wind"], axes):
  sns.boxplot(data = opsd_daily, x = "Month", y = name, ax = ax)
  ax.set_ylabel("GWh")
  ax.set_title(name)
  if ax != axes[-1]:
    ax.set_xlabel("")
plt.show()

# %% [markdown]
# # Frequencies

# %%
pd.date_range ("1998-03-10", "1998-03-15", freq ="D")
# Out:
# DatetimeIndex(['1998-03-10', '1998-03-11', '1998-03-12', '1998-03-13',
#                '1998-03-14', '1998-03-15'],
#               dtype='datetime64[ns]', freq='D')

# %%
time_sample = ["2013-02-03", "2013-02-06", "2013-02-08"]
consum_sample_df = opsd_daily.loc[time_sample, ['Consumption']].copy()
print(consum_sample_df)
# Out:
#             Consumption
# Date
# 2013-02-03     1109.639
# 2013-02-06     1451.449
# 2013-02-08     1433.098

# %%
# Convert the data to daily frequency, without filling any missings
consum_freq = consum_sample_df.asfreq("D")
# Create a column with missings forward filled
consum_freq["Consumption - Forward Fill"] = consum_freq["Consumption"].ffill()
consum_freq
# Out:
#             Consumption  Consumption - Forward Fill
# Date
# 2013-02-03     1109.639                    1109.639
# 2013-02-04          NaN                    1109.639
# 2013-02-05          NaN                    1109.639
# 2013-02-06     1451.449                    1451.449
# 2013-02-07          NaN                    1451.449
# 2013-02-08     1433.098                    1433.098

# %%
consum_sample_df = opsd_daily.loc[time_sample, ["Consumption"]].copy()
consum_freq = consum_sample_df.asfreq("D")
consum_freq["Consumption - Forward Fill"] = consum_freq["Consumption"].ffill()
consum_freq
# Out:
#             Consumption  Consumption - Forward Fill
# Date
# 2013-02-03     1109.639                    1109.639
# 2013-02-04          NaN                    1109.639
# 2013-02-05          NaN                    1109.639
# 2013-02-06     1451.449                    1451.449
# 2013-02-07          NaN                    1451.449
# 2013-02-08     1433.098                    1433.098

# %% [markdown]
# # Resampling

# %%
data_columns = ["Consumption", "Wind", "Solar", "Wind+Solar"]
opsd_weekly_mean = opsd_daily[data_columns].resample("W").mean()
opsd_weekly_mean.head(3)
# Out:
#             Consumption  Wind  Solar  Wind+Solar
# Date
# 2006-01-01  1069.184000   NaN    NaN         NaN
# 2006-01-08  1381.300143   NaN    NaN         NaN
# 2006-01-15  1486.730286   NaN    NaN         NaN

# %%
print(opsd_daily.shape[0])
print(opsd_weekly_mean.shape[0])
# Out:
# 4383
# 627

# %%
start,end = "2017-01", "2017-06"
fig, ax = plt.subplots()
ax.plot(opsd_daily.loc[start:end, "Solar"],
        marker = '.', linestyle = '-', linewidth=0.5, label="Daily")

ax.plot(opsd_weekly_mean.loc[start:end, "Solar"],
        marker="o", markersize=8, linestyle="-", label="Weekly Mean Resample")
ax.set_ylabel("Solar Production (GWh)")
ax.legend()
plt.show()

# %%
opsd_annual = opsd_daily[data_columns].resample("YE").sum(min_count = 360)
# The default index of the resampled DataFrame is the last day of each year,
# ("2006-12-31", "2007-12-31", etc.) so to make life easier, set the index
# to the year component
opsd_annual = opsd_annual.set_index(opsd_annual.index.year)
opsd_annual.index.name = "Year"
opsd_annual["Wind+Solar/Consumption"] = opsd_annual['Wind+Solar']/ opsd_annual['Consumption']

# %%
opsd_annual
# Out:
#        Consumption        Wind      Solar  Wind+Solar  Wind+Solar/Consumption
# Year
# 2006  489068.53600         NaN        NaN         NaN                     NaN
# 2007  496631.84700         NaN        NaN         NaN                     NaN
# 2008  495570.87600         NaN        NaN         NaN                     NaN
# 2009  459737.42800         NaN        NaN         NaN                     NaN
# 2010  488588.70000   35911.777        NaN         NaN                     NaN
# 2011  484814.08600   44032.951        NaN         NaN                     NaN
# 2012  469574.75400   45862.667  27887.332   73749.999                0.157057
# 2013  463336.85300   47197.832  29559.780   76697.443                0.165533
# 2014  504164.82100   51107.672  32498.307   83370.502                0.165364
# 2015  505264.56300   77468.994  34907.138  112376.132                0.222410
# 2016  505927.35400   77008.126  34562.824  111570.950                0.220528
# ...

# %%
ax = opsd_annual.loc[2012:,'Wind+Solar/Consumption'].plot.bar(figsize = (15,10))
ax.set_ylabel("Fraction")
ax.set_ylim(0, 0.3)
ax.set_title("Wind + Solar Share of Annual Electricity Consumption")
plt.xticks(rotation=0)
plt.show()

# %%
opsd_7d = opsd_daily[data_columns].rolling(7, center=True).mean()
opsd_7d
# Out:
#             Consumption        Wind      Solar  Wind+Solar
# Date
# 2006-01-01          NaN         NaN        NaN         NaN
# 2006-01-02          NaN         NaN        NaN         NaN
# 2006-01-03          NaN         NaN        NaN         NaN
# 2006-01-04  1361.471429         NaN        NaN         NaN
# 2006-01-05  1381.300143         NaN        NaN         NaN
# ...                 ...         ...        ...         ...
# 2017-12-27  1208.214129  617.734286  17.807143  635.541429
# 2017-12-28  1203.265211  604.699143  19.240143  623.939286
# 2017-12-29          NaN         NaN        NaN         NaN
# 2017-12-30          NaN         NaN        NaN         NaN
# 2017-12-31          NaN         NaN        NaN         NaN
#
# [4383 rows x 4 columns]

# %% [markdown]
# Ở đây, 2006-01-01 đến 2006-01-07 được đánh nhãn là 2006-01-04, 2006-01-02 đến 2006-01-08 được đánh nhãn là 2006-01-05, tương tự cho các dòng khác.

# %%
import matplotlib.dates as mdates

opsd_365d = opsd_daily[data_columns].rolling(
    window = 365,
    min_periods=360,
    center=True,
).mean()

fig, ax = plt.subplots()
ax.plot(opsd_daily["Consumption"], marker=".", markersize=2, color="0.6",
          linestyle="None", label="Daily")
ax.plot(opsd_7d["Consumption"], linewidth=2, label="7-d Rolling Mean")
ax.plot(opsd_365d["Consumption"], linewidth=2, label="Trend (365-d Rolling Mean)")
# Set x-ticks to yearly interval and add legend and labels
ax.xaxis.set_major_locator(mdates.YearLocator())
ax.legend()
plt.show()

# %%
fig, ax = plt.subplots()
for nm in ["Wind", "Solar", "Wind+Solar"]:
  ax.plot(opsd_365d[nm], label=nm)
  # Set x-ticks to yearly interval, adjust y-axis limits, add legend and labels
  ax.xaxis.set_major_locator(mdates.YearLocator())
  ax.set_ylim(0, 400)
  ax.legend()
  ax.set_ylabel("Production (GWh)")
  ax.set_title("Trends in Electricity Production (365-d Rolling Means)")
plt.show()
